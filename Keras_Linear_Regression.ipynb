# %%
# Import library
import pandas  as pd #Data manipulation
import numpy as np #Data manipulation
import random as rnd
import matplotlib.pyplot as plt # Visualization
from matplotlib.ticker import StrMethodFormatter
from sklearn.preprocessing import LabelBinarizer #Data manipulation
from sklearn.preprocessing import MinMaxScaler #Data manipulation
from sklearn.model_selection import train_test_split #Data manipulation
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense
from tensorflow.keras.models import Model
from tensorflow.keras.optimizers import Adam


pd.options.display.max_rows = 1500
pd.options.display.max_columns = 999

# %% [markdown]
# Our data (.csv) is read in from the specified path and loaded into a pandas dataFrame.
#
#
#
#
# Might be good to consider dropping useless columns from our data after the ttsplit.
# If a col has enough data to pass our initial test it might get split unevenly and end up being under
# the threshold for usefulness in either or train or test data...

# %%
path = "./housePriceData/"
df = pd.read_csv(path+'train.csv')

# %% [markdown]
# Firstly, lets check the data set for the presence of null values.

# %%
df.isnull().sum()
# Out:
# Id                  0
# MSSubClass          0
# MSZoning            0
# LotFrontage       259
# LotArea             0
# Street              0
# Alley            1369
# LotShape            0
# LandContour         0
# Utilities           0
# LotConfig           0
# LandSlope           0
# Neighborhood        0
# Condition1          0
# Condition2          0
# BldgType            0
# HouseStyle          0
# OverallQual         0
# OverallCond         0
# YearBuilt           0
# YearRemodAdd        0
# RoofStyle           0
# RoofMatl            0
# Exterior1st         0
# Exterior2nd         0
# MasVnrType          8
# MasVnrArea          8
# ExterQual           0
# ExterCond           0
# Foundation          0
# BsmtQual           37
# BsmtCond           37
# BsmtExposure       38
# BsmtFinType1       37
# BsmtFinSF1          0
# BsmtFinType2       38
# BsmtFinSF2          0
# BsmtUnfSF           0
# TotalBsmtSF         0
# Heating             0
# HeatingQC           0
# CentralAir          0
# Electrical          1
# 1stFlrSF            0
# 2ndFlrSF            0
# LowQualFinSF        0
# GrLivArea           0
# BsmtFullBath        0
# BsmtHalfBath        0
# FullBath            0
# HalfBath            0
# BedroomAbvGr        0
# KitchenAbvGr        0
# KitchenQual         0
# TotRmsAbvGrd        0
# Functional          0
# Fireplaces          0
# FireplaceQu       690
# GarageType         81
# GarageYrBlt        81
# GarageFinish       81
# GarageCars          0
# GarageArea          0
# GarageQual         81
# GarageCond         81
# PavedDrive          0
# WoodDeckSF          0
# OpenPorchSF         0
# EnclosedPorch       0
# 3SsnPorch           0
# ScreenPorch         0
# PoolArea            0
# PoolQC           1453
# Fence            1179
# MiscFeature      1406
# MiscVal             0
# MoSold              0
# YrSold              0
# SaleType            0
# SaleCondition       0
# SalePrice           0
# dtype: int64

# %% [markdown]
# There are a significant number of null values present within several columns of the data set. This will have a detremental effect on our model so it is important that we deal with them accordingly.
#
# Research carried out during the course of this project indiacted the prescene of "Abnormal" entries in the SaleCondition column. In the column description that accompanies the data set the "Abnormal" entry to the SaleCondition column is described as such:
#
# "Abnorml:	Abnormal Sale -  trade, foreclosure, short sale"
#
# I deemed it appropriate to drop entries of this kind due to their nature.

# %%
df.dropna(1, thresh=((df.shape[0]) * 0.5), inplace=True)
df.dropna(0, thresh=(df.shape[1] * 0.5), inplace=True)
df.replace(np.nan,0, inplace = True)
df.dropna(subset = ["SalePrice"], inplace = True)
df.drop(['Id'], axis=1, inplace = True)
abnormalSales = df[df.SaleCondition == "Abnorml"]
df.drop(abnormalSales.index, inplace = True)

# %% [markdown]
# Any remaining null values are given a value of 0.

# %%
df.replace(np.nan,0, inplace = True)

# %% [markdown]
# A quick check to verify that we have removed all instances of null values throughout our data set.

# %%
df.isnull().sum()
# Out:
# MSSubClass       0
# MSZoning         0
# LotFrontage      0
# LotArea          0
# Street           0
# LotShape         0
# LandContour      0
# Utilities        0
# LotConfig        0
# LandSlope        0
# Neighborhood     0
# Condition1       0
# Condition2       0
# BldgType         0
# HouseStyle       0
# OverallQual      0
# OverallCond      0
# YearBuilt        0
# YearRemodAdd     0
# RoofStyle        0
# RoofMatl         0
# Exterior1st      0
# Exterior2nd      0
# MasVnrType       0
# MasVnrArea       0
# ExterQual        0
# ExterCond        0
# Foundation       0
# BsmtQual         0
# BsmtCond         0
# BsmtExposure     0
# BsmtFinType1     0
# BsmtFinSF1       0
# BsmtFinType2     0
# BsmtFinSF2       0
# BsmtUnfSF        0
# TotalBsmtSF      0
# Heating          0
# HeatingQC        0
# CentralAir       0
# Electrical       0
# 1stFlrSF         0
# 2ndFlrSF         0
# LowQualFinSF     0
# GrLivArea        0
# BsmtFullBath     0
# BsmtHalfBath     0
# FullBath         0
# HalfBath         0
# BedroomAbvGr     0
# KitchenAbvGr     0
# KitchenQual      0
# TotRmsAbvGrd     0
# Functional       0
# Fireplaces       0
# FireplaceQu      0
# GarageType       0
# GarageYrBlt      0
# GarageFinish     0
# GarageCars       0
# GarageArea       0
# GarageQual       0
# GarageCond       0
# PavedDrive       0
# WoodDeckSF       0
# OpenPorchSF      0
# EnclosedPorch    0
# 3SsnPorch        0
# ScreenPorch      0
# PoolArea         0
# MiscVal          0
# MoSold           0
# YrSold           0
# SaleType         0
# SaleCondition    0
# SalePrice        0
# dtype: int64

# %% [markdown]
# Any rows that do not have a sale price are dropped. ID is also dropped at this point as it does not influece the dependant variable (SalePrice) in any way.

# %% [markdown]
# SalePrice is the dependant variable in this data set, it plays an important so let's take a close look at it:

# %%
 def plotHist(df, column):
    
    ax = df.hist(column=column, bins=25, grid=False, figsize=(12,8), color='#86bf91', zorder=2, rwidth=0.9)

    ax = ax[0]
    for x in ax:

        # Despine
        x.spines['right'].set_visible(False)
        x.spines['top'].set_visible(False)
        x.spines['left'].set_visible(False)

        # Switch off ticks
        x.tick_params(axis="both", which="both", bottom="off", top="off", labelbottom="on", left="off", right="off", labelleft="on")

        # Draw horizontal axis lines
        vals = x.get_yticks()
        for tick in vals:
            x.axhline(y=tick, linestyle='dashed', alpha=0.4, color='#eeeeee', zorder=1)

        # Remove title
        x.set_title("")

        # Set x-axis label
        x.set_xlabel(column, labelpad=20, weight='bold', size=12)

        # Set y-axis label
        x.set_ylabel("Number of Entries", labelpad=20, weight='bold', size=12)

        # Format y-axis label
        x.yaxis.set_major_formatter(StrMethodFormatter('{x:,g}'))

# %%
plotHist(df, 'SalePrice')

# %%
meanSalePrice = df.SalePrice.mean()
print("Mean SalePrice: {:.2f}".format (meanSalePrice))
salePriceStd = df.SalePrice.std()
print("Standard Deviation of SalePrice: {:.2f}".format (salePriceStd))
# Out:
# Mean SalePrice: 183477.38
# Standard Deviation of SalePrice: 78620.42

# %% [markdown]
# You can see above that while the majority of house sales fall between 100,000 and 300,000 there are some outlying sales up around the 500,000+ range. This outlying data resides at the edges of the distribution and so is not reflective of the main body of the data.
#
# With this in mind it is tempting to drop the rows contianing these outlying values and doing so could lead to in increase in statistical significance. However, they are natural members of the dataset and so must be included if the model is to be realistic in it's ambitions.

# %%
#outliersHigh = df[df.SalePrice > meanSalePrice+(3*salePriceStd)]
#df.drop(outliersHigh.index, inplace = True)

#outliersLow = df[df.SalePrice < 50000]
#df.drop(outliersLow.index, inplace = True)

#plotHist(df, 'SalePrice')

# %% [markdown]
# Data is split into two random subsets, corresponding to our training and validation data.
# "test_size=0.20" indicates that we utilize 20% of our data for testing, the remaining 80% to be used for training.

# %%
rnd.seed()
(train, test) = train_test_split(df, test_size=0.20, random_state=rnd.randint(1, 100))

# %% [markdown]
# Scale dependant variable

# %%
maxSale = train["SalePrice"].max()
trainY = train["SalePrice"] / maxSale
testY = test["SalePrice"] / maxSale

# %% [markdown]
# TOdo: auto grab the below names and auto trim them to match the row cull

# %%
catCol = ['MSZoning', 'Street', 'LotShape', 'LandContour', 'Utilities', 'LotConfig', 'LandSlope', 'Neighborhood', 'Condition1',
          'Condition2', 'BldgType', 'HouseStyle', 'YearBuilt', 'RoofStyle', 'RoofMatl', 'Exterior1st', 'Exterior2nd', 'MasVnrType', 'ExterQual',
          'ExterCond', 'Foundation', 'BsmtQual', 'BsmtCond', 'BsmtExposure', 'BsmtFinType1', 'BsmtFinType2', 'Heating', 'HeatingQC',
          'CentralAir', 'Electrical', 'KitchenQual', 'Functional', 'GarageType', 'GarageYrBlt', 'GarageFinish', 'GarageQual', 'GarageCond',
          'PavedDrive', 'SaleType', 'SaleCondition']

conCol  = ['MSSubClass','LotFrontage', 'LotArea', 'OverallQual', 'OverallCond', 'YearRemodAdd','MasVnrArea', 'BsmtFinSF1',
           'BsmtFinSF2', 'BsmtUnfSF', 'TotalBsmtSF', '1stFlrSF', '2ndFlrSF', 'LowQualFinSF', 'GrLivArea', 'BsmtFullBath', 'BsmtHalfBath',
           'FullBath', 'HalfBath', 'BedroomAbvGr', 'KitchenAbvGr', 'TotRmsAbvGrd', 'Fireplaces', 'GarageCars', 'GarageArea',
           'WoodDeckSF', 'OpenPorchSF', 'EnclosedPorch', '3SsnPorch', 'ScreenPorch', 'PoolArea', 'MiscVal', 'MoSold', 'YrSold']

# %%
lb = LabelBinarizer()

trainCat = np.array([]).reshape(len(train), 0)
testCat = np.array([]).reshape(len(test), 0)

for i in catCol:   
    #talk about asType(str) here
    lb.fit(df[i].astype(str))
    
    temp = lb.transform(train[i].astype(str))
    trainCat = np.hstack([trainCat, temp[:,1:]])
    
    temp = lb.transform(test[i].astype(str))
    testCat = np.hstack([testCat, temp[:,1:]])
    
print(trainCat.shape)
mms = MinMaxScaler()
#talk about fit_Transform vs transform
trainCon = mms.fit_transform(train[conCol])
testCon = mms.transform(test[conCol])

trainX = np.hstack([trainCat, trainCon])
testX = np.hstack([testCat, testCon])
# Out:
# (1087, 406)

# %% [markdown]
# The model is defined below. To begin a Sequential object is defined. Firstly the input layer is defined and then added, followed by the hidden layers.
#
# The nodes in the input and hidden layers in the model have a rectified linear activation function applied to them. These nodes will either output the positive input the recieve or zero.
#
# The ouput layer of the model is then added, it contains a single node and recieves linear activation.
#
# The Adam optimiser is selected, Adam applies a type stochastic gradient descent in an attempt to minimise the loss function of the model. Adam is regarded as being lightweight so it is an appropriate choice for this project.
#
# The model is compiled with a mean absolute percentage error loss function. I tried this with a mean squared error function but feel MAE worked better.

# %%
model = Sequential()

model.add(Dense(16, input_dim=trainX.shape[1], activation="relu"))

model.add(Dense(32, activation="relu"))
model.add(Dense(56, activation="relu"))
model.add(Dense(32, activation="relu"))
model.add(Dense(16, activation="relu"))
model.add(Dense(8, activation= "relu"))

model.add(Dense(1, activation="linear"))

opt = Adam(lr=1e-3, decay=1e-3 / 100)

model.compile(loss="mean_absolute_percentage_error", optimizer=opt)

# %% [markdown]
# The model is trained in the below cell. After some experimentation I settled on an epoch count of 100 with a batch size of 16.
# When using a higher epoch count I noticed my training and validation accuracies were diverging.

# %%
print("[INFO] training model...")
history = model.fit(x=trainX, 
                    y=trainY, 
                    validation_data=(testX, testY), 
                    epochs=100, 
                    batch_size=16, 
                    use_multiprocessing=True)
# Out:
# [INFO] training model...
# Train on 1087 samples, validate on 272 samples
# Epoch 1/100
# 1087/1087 [==============================] - 1s 504us/sample - loss: 25.4237 - val_loss: 23.6792
# Epoch 2/100
# 1087/1087 [==============================] - 0s 97us/sample - loss: 17.7876 - val_loss: 19.9004
# Epoch 3/100
# 1087/1087 [==============================] - 0s 97us/sample - loss: 15.6117 - val_loss: 17.6333
# Epoch 4/100
# 1087/1087 [==============================] - 0s 96us/sample - loss: 13.7476 - val_loss: 17.2517
# Epoch 5/100
# 1087/1087 [==============================] - 0s 97us/sample - loss: 12.0159 - val_loss: 15.0832
# Epoch 6/100
# 1087/1087 [==============================] - 0s 97us/sample - loss: 10.8212 - val_loss: 16.5950
# Epoch 7/100
# 1087/1087 [==============================] - 0s 99us/sample - loss: 9.6167 - val_loss: 14.4442
# Epoch 8/100
# 1087/1087 [==============================] - 0s 95us/sample - loss: 8.9391 - val_loss: 14.0603
# Epoch 9/100
# 1087/1087 [==============================] - 0s 95us/sample - loss: 8.4263 - val_loss: 12.5871
# Epoch 10/100
# 1087/1087 [==============================] - 0s 96us/sample - loss: 8.1118 - val_loss: 12.8803
# Epoch 11/100
# 1087/1087 [==============================] - 0s 97us/sample - loss: 8.0254 - val_loss: 13.1541
# Epoch 12/100
# 1087/1087 [==============================] - 0s 98us/sample - loss: 7.3513 - val_loss: 12.8867
# Epoch 13/100
# 1087/1087 [==============================] - 0s 98us/sample - loss: 8.2426 - val_loss: 13.0479
# Epoch 14/100
# 1087/1087 [==============================] - 0s 100us/sample - loss: 6.4937 - val_loss: 11.8315
# Epoch 15/100
# 1087/1087 [==============================] - 0s 99us/sample - loss: 6.4330 - val_loss: 12.6654
# Epoch 16/100
# 1087/1087 [==============================] - 0s 99us/sample - loss: 7.0052 - val_loss: 11.6502
# Epoch 17/100
# 1087/1087 [==============================] - 0s 96us/sample - loss: 6.0426 - val_loss: 11.6815
# Epoch 18/100
# 1087/1087 [==============================] - 0s 97us/sample - loss: 5.8858 - val_loss: 11.7634
# Epoch 19/100
# 1087/1087 [==============================] - 0s 99us/sample - loss: 5.7171 - val_loss: 11.6654
# Epoch 20/100
# 1087/1087 [==============================] - 0s 97us/sample - loss: 5.6039 - val_loss: 12.5578
# Epoch 21/100
# 1087/1087 [==============================] - 0s 98us/sample - loss: 6.0443 - val_loss: 11.4935
# Epoch 22/100
# 1087/1087 [==============================] - 0s 97us/sample - loss: 6.3023 - val_loss: 11.8437
# Epoch 23/100
# 1087/1087 [==============================] - 0s 97us/sample - loss: 5.6452 - val_loss: 11.6865
# Epoch 24/100
# 1087/1087 [==============================] - 0s 97us/sample - loss: 4.9963 - val_loss: 12.9620
# Epoch 25/100
# 1087/1087 [==============================] - 0s 96us/sample - loss: 5.0308 - val_loss: 11.4375
# Epoch 26/100
# 1087/1087 [==============================] - 0s 96us/sample - loss: 4.9178 - val_loss: 11.4655
# Epoch 27/100
# 1087/1087 [==============================] - 0s 98us/sample - loss: 4.9583 - val_loss: 11.4852
# Epoch 28/100
# 1087/1087 [==============================] - 0s 99us/sample - loss: 4.9222 - val_loss: 11.1700
# Epoch 29/100
# 1087/1087 [==============================] - 0s 97us/sample - loss: 4.6607 - val_loss: 12.1257
# Epoch 30/100
# 1087/1087 [==============================] - 0s 99us/sample - loss: 4.6613 - val_loss: 12.1956
# Epoch 31/100
# 1087/1087 [==============================] - 0s 99us/sample - loss: 4.7769 - val_loss: 11.5628
# Epoch 32/100
# 1087/1087 [==============================] - 0s 97us/sample - loss: 4.7371 - val_loss: 11.8474
# Epoch 33/100
# 1087/1087 [==============================] - 0s 96us/sample - loss: 4.3129 - val_loss: 11.2319
# Epoch 34/100
# 1087/1087 [==============================] - 0s 96us/sample - loss: 4.2278 - val_loss: 11.9251
# Epoch 35/100
# 1087/1087 [==============================] - 0s 98us/sample - loss: 4.8392 - val_loss: 12.1265
# Epoch 36/100
# 1087/1087 [==============================] - 0s 98us/sample - loss: 4.3571 - val_loss: 11.2970
# Epoch 37/100
# 1087/1087 [==============================] - 0s 98us/sample - loss: 4.3029 - val_loss: 11.6509
# Epoch 38/100
# 1087/1087 [==============================] - 0s 97us/sample - loss: 4.2240 - val_loss: 11.9052
# Epoch 39/100
# 1087/1087 [==============================] - 0s 98us/sample - loss: 4.7802 - val_loss: 11.9266
# Epoch 40/100
# 1087/1087 [==============================] - 0s 96us/sample - loss: 4.3489 - val_loss: 11.5884
# Epoch 41/100
# 1087/1087 [==============================] - 0s 98us/sample - loss: 4.0671 - val_loss: 11.1438
# Epoch 42/100
# 1087/1087 [==============================] - 0s 98us/sample - loss: 4.1016 - val_loss: 11.3290
# Epoch 43/100
# 1087/1087 [==============================] - 0s 97us/sample - loss: 3.8744 - val_loss: 11.3173
# Epoch 44/100
# 1087/1087 [==============================] - 0s 99us/sample - loss: 3.7948 - val_loss: 11.5894
# Epoch 45/100
# 1087/1087 [==============================] - 0s 99us/sample - loss: 3.7466 - val_loss: 11.3516
# Epoch 46/100
# 1087/1087 [==============================] - 0s 98us/sample - loss: 3.6872 - val_loss: 12.0138
# Epoch 47/100
# 1087/1087 [==============================] - 0s 96us/sample - loss: 4.3222 - val_loss: 11.6363
# Epoch 48/100
# 1087/1087 [==============================] - 0s 97us/sample - loss: 3.7901 - val_loss: 11.0195
# Epoch 49/100
# 1087/1087 [==============================] - 0s 97us/sample - loss: 3.9768 - val_loss: 11.1164
# Epoch 50/100
# 1087/1087 [==============================] - 0s 98us/sample - loss: 4.0156 - val_loss: 11.3825
# Epoch 51/100
# 1087/1087 [==============================] - 0s 99us/sample - loss: 3.6151 - val_loss: 11.1748
# Epoch 52/100
# 1087/1087 [==============================] - 0s 98us/sample - loss: 3.3373 - val_loss: 11.0444
# Epoch 53/100
# 1087/1087 [==============================] - 0s 99us/sample - loss: 3.7513 - val_loss: 11.2067
# Epoch 54/100
# 1087/1087 [==============================] - 0s 96us/sample - loss: 3.4195 - val_loss: 10.9931
# Epoch 55/100
# 1087/1087 [==============================] - 0s 96us/sample - loss: 4.0385 - val_loss: 11.5320
# Epoch 56/100
# 1087/1087 [==============================] - 0s 96us/sample - loss: 3.3932 - val_loss: 11.1327
# Epoch 57/100
# 1087/1087 [==============================] - 0s 100us/sample - loss: 3.4988 - val_loss: 11.0323
# Epoch 58/100
# 1087/1087 [==============================] - 0s 96us/sample - loss: 3.2849 - val_loss: 10.8439
# Epoch 59/100
# 1087/1087 [==============================] - 0s 98us/sample - loss: 3.4436 - val_loss: 11.4553
# Epoch 60/100
# 1087/1087 [==============================] - 0s 94us/sample - loss: 3.1882 - val_loss: 11.0035
# Epoch 61/100
# 1087/1087 [==============================] - 0s 96us/sample - loss: 3.3543 - val_loss: 11.0121
# Epoch 62/100
# 1087/1087 [==============================] - 0s 98us/sample - loss: 3.5658 - val_loss: 11.3230
# Epoch 63/100
# 1087/1087 [==============================] - 0s 98us/sample - loss: 3.2624 - val_loss: 10.9485
# Epoch 64/100
# 1087/1087 [==============================] - 0s 97us/sample - loss: 3.1000 - val_loss: 11.0575
# Epoch 65/100
# 1087/1087 [==============================] - 0s 95us/sample - loss: 3.5738 - val_loss: 11.3265
# Epoch 66/100
# 1087/1087 [==============================] - 0s 96us/sample - loss: 3.1914 - val_loss: 10.8424
# Epoch 67/100
# 1087/1087 [==============================] - 0s 96us/sample - loss: 3.0024 - val_loss: 11.0938
# Epoch 68/100
# 1087/1087 [==============================] - 0s 96us/sample - loss: 3.0627 - val_loss: 11.2373
# Epoch 69/100
# 1087/1087 [==============================] - 0s 96us/sample - loss: 3.1949 - val_loss: 11.5069
# Epoch 70/100
# 1087/1087 [==============================] - 0s 95us/sample - loss: 2.9533 - val_loss: 10.7904
# Epoch 71/100
# 1087/1087 [==============================] - 0s 98us/sample - loss: 2.7513 - val_loss: 11.1822
# Epoch 72/100
# 1087/1087 [==============================] - 0s 97us/sample - loss: 3.9131 - val_loss: 11.6784
# Epoch 73/100
# 1087/1087 [==============================] - 0s 99us/sample - loss: 3.3500 - val_loss: 10.8055
# Epoch 74/100
# 1087/1087 [==============================] - 0s 97us/sample - loss: 3.0899 - val_loss: 10.9696
# Epoch 75/100
# 1087/1087 [==============================] - 0s 97us/sample - loss: 2.8035 - val_loss: 10.9657
# Epoch 76/100
# 1087/1087 [==============================] - 0s 96us/sample - loss: 2.8734 - val_loss: 11.2198
# Epoch 77/100
# 1087/1087 [==============================] - 0s 96us/sample - loss: 2.8374 - val_loss: 11.4973
# Epoch 78/100
# 1087/1087 [==============================] - 0s 97us/sample - loss: 2.9063 - val_loss: 10.9171
# Epoch 79/100
# 1087/1087 [==============================] - 0s 94us/sample - loss: 2.9573 - val_loss: 12.5069
# Epoch 80/100
# 1087/1087 [==============================] - 0s 96us/sample - loss: 3.0564 - val_loss: 11.2026
# Epoch 81/100
# 1087/1087 [==============================] - 0s 96us/sample - loss: 2.7216 - val_loss: 11.2272
# Epoch 82/100
# 1087/1087 [==============================] - 0s 96us/sample - loss: 2.6322 - val_loss: 11.3663
# Epoch 83/100
# 1087/1087 [==============================] - 0s 95us/sample - loss: 2.7900 - val_loss: 11.0671
# Epoch 84/100
# 1087/1087 [==============================] - 0s 96us/sample - loss: 2.7458 - val_loss: 11.2113
# Epoch 85/100
# 1087/1087 [==============================] - 0s 96us/sample - loss: 2.7969 - val_loss: 11.1469
# Epoch 86/100
# 1087/1087 [==============================] - 0s 97us/sample - loss: 2.8398 - val_loss: 11.0364
# Epoch 87/100
# 1087/1087 [==============================] - 0s 99us/sample - loss: 2.5838 - val_loss: 11.2011
# Epoch 88/100
# 1087/1087 [==============================] - 0s 101us/sample - loss: 2.7153 - val_loss: 11.0707
# Epoch 89/100
# 1087/1087 [==============================] - 0s 103us/sample - loss: 2.4349 - val_loss: 11.0084
# Epoch 90/100
# 1087/1087 [==============================] - 0s 104us/sample - loss: 2.7555 - val_loss: 10.9455
# Epoch 91/100
# 1087/1087 [==============================] - 0s 106us/sample - loss: 2.6102 - val_loss: 11.3801
# Epoch 92/100
# 1087/1087 [==============================] - 0s 99us/sample - loss: 3.1161 - val_loss: 10.9777
# Epoch 93/100
# 1087/1087 [==============================] - 0s 97us/sample - loss: 2.7263 - val_loss: 11.2174
# Epoch 94/100
# 1087/1087 [==============================] - 0s 99us/sample - loss: 2.6206 - val_loss: 11.0748
# Epoch 95/100
# 1087/1087 [==============================] - 0s 101us/sample - loss: 2.5762 - val_loss: 11.1362
# Epoch 96/100
# 1087/1087 [==============================] - 0s 98us/sample - loss: 3.1413 - val_loss: 11.2337
# Epoch 97/100
# 1087/1087 [==============================] - 0s 104us/sample - loss: 2.7125 - val_loss: 10.8455
# Epoch 98/100
# 1087/1087 [==============================] - 0s 99us/sample - loss: 2.4894 - val_loss: 11.1032
# Epoch 99/100
# 1087/1087 [==============================] - 0s 92us/sample - loss: 2.6764 - val_loss: 10.6792
# Epoch 100/100
# 1087/1087 [==============================] - 0s 102us/sample - loss: 2.7993 - val_loss: 10.8395

# %% [markdown]
# Below, prediction data is extracted from the model. The normalised prediction values are returned to their original scale. The predictions and their accuracies are printed out and some relevant statistical variables are determined.

# %%
# make predictions using the testing data
predictions = model.predict(testX)
predictions = predictions.flatten()

#predictions are returned to the natural scale of prices by multiplying them by the max sale value that was used to scale the 
#train and test data.
predictionsDenormalised = predictions * maxSale

for (i, j) in zip(predictionsDenormalised, test["SalePrice"]):
    error = ( abs(i - j) / j ) * 100
    print( ("Prediction:{:7d}  -  Actual:{:7d}  -  Accuracy: {:.2f}%".format(int(i), j, (100 - error))))


#difference corresponds to the difference between the predictions and the test 'SalePrice' values.
difference = predictions - testY

percentDiff = (difference / testY) * 100
absPercentDiff = np.abs(percentDiff)
accuracies = 100 - absPercentDiff
averageAcc = np.mean(accuracies)
mean = np.mean(absPercentDiff)
std = np.std(absPercentDiff)
# Out:
# Prediction: 177641  -  Actual: 175900  -  Accuracy: 99.01%
# Prediction:  76219  -  Actual:  73000  -  Accuracy: 95.59%
# Prediction: 170442  -  Actual: 167900  -  Accuracy: 98.49%
# Prediction: 125009  -  Actual: 127000  -  Accuracy: 98.43%
# Prediction:  93197  -  Actual:  81000  -  Accuracy: 84.94%
# Prediction: 178609  -  Actual: 136500  -  Accuracy: 69.15%
# Prediction: 117925  -  Actual: 135000  -  Accuracy: 87.35%
# Prediction: 177216  -  Actual: 157500  -  Accuracy: 87.48%
# Prediction: 124144  -  Actual: 130000  -  Accuracy: 95.50%
# Prediction: 175489  -  Actual: 163900  -  Accuracy: 92.93%
# Prediction: 116055  -  Actual: 100000  -  Accuracy: 83.94%
# Prediction: 199040  -  Actual: 193000  -  Accuracy: 96.87%
# Prediction: 145331  -  Actual: 129000  -  Accuracy: 87.34%
# Prediction: 130453  -  Actual: 140000  -  Accuracy: 93.18%
# Prediction: 149493  -  Actual: 148000  -  Accuracy: 98.99%
# Prediction: 173975  -  Actual: 172500  -  Accuracy: 99.14%
# Prediction: 196433  -  Actual: 215000  -  Accuracy: 91.36%
# Prediction: 229008  -  Actual: 239799  -  Accuracy: 95.50%
# Prediction: 307404  -  Actual: 348000  -  Accuracy: 88.33%
# Prediction: 229600  -  Actual: 181000  -  Accuracy: 73.15%
# Prediction: 230675  -  Actual: 232000  -  Accuracy: 99.43%
# Prediction: 239024  -  Actual: 190000  -  Accuracy: 74.20%
# Prediction: 148578  -  Actual: 145000  -  Accuracy: 97.53%
# Prediction: 138039  -  Actual:  89471  -  Accuracy: 45.72%
# Prediction: 136942  -  Actual: 137500  -  Accuracy: 99.59%
# Prediction: 205066  -  Actual: 188000  -  Accuracy: 90.92%
# Prediction: 126771  -  Actual: 120000  -  Accuracy: 94.36%
# Prediction: 103473  -  Actual:  98000  -  Accuracy: 94.41%
# Prediction: 139468  -  Actual: 147000  -  Accuracy: 94.88%
# Prediction:  66523  -  Actual:  52500  -  Accuracy: 73.29%
# Prediction: 103604  -  Actual: 106500  -  Accuracy: 97.28%
# Prediction: 299965  -  Actual: 341000  -  Accuracy: 87.97%
# Prediction: 205981  -  Actual: 244400  -  Accuracy: 84.28%
# Prediction: 156747  -  Actual: 170000  -  Accuracy: 92.20%
# Prediction: 386426  -  Actual: 412500  -  Accuracy: 93.68%
# Prediction: 289317  -  Actual: 335000  -  Accuracy: 86.36%
# Prediction: 107517  -  Actual: 125000  -  Accuracy: 86.01%
# Prediction: 132221  -  Actual: 113000  -  Accuracy: 82.99%
# Prediction: 212277  -  Actual: 193500  -  Accuracy: 90.30%
# Prediction: 245482  -  Actual: 272000  -  Accuracy: 90.25%
# Prediction: 166623  -  Actual: 176500  -  Accuracy: 94.40%
# Prediction:  99073  -  Actual: 115000  -  Accuracy: 86.15%
# Prediction:  94019  -  Actual:  83500  -  Accuracy: 87.40%
# Prediction: 109821  -  Actual: 140200  -  Accuracy: 78.33%
# Prediction: 306552  -  Actual: 200624  -  Accuracy: 47.20%
# Prediction: 284162  -  Actual: 260000  -  Accuracy: 90.71%
# Prediction: 116640  -  Actual: 109900  -  Accuracy: 93.87%
# Prediction:  93228  -  Actual: 115000  -  Accuracy: 81.07%
# Prediction: 138227  -  Actual: 151000  -  Accuracy: 91.54%
# Prediction:  86465  -  Actual: 100000  -  Accuracy: 86.47%
# Prediction:  99519  -  Actual: 109500  -  Accuracy: 90.89%
# Prediction: 176024  -  Actual: 158000  -  Accuracy: 88.59%
# Prediction: 529226  -  Actual: 466500  -  Accuracy: 86.55%
# Prediction: 313133  -  Actual: 320000  -  Accuracy: 97.85%
# Prediction:  99007  -  Actual: 119500  -  Accuracy: 82.85%
# Prediction:  81313  -  Actual:  99900  -  Accuracy: 81.40%
# Prediction: 180949  -  Actual: 170000  -  Accuracy: 93.56%
# Prediction: 122276  -  Actual: 127000  -  Accuracy: 96.28%
# Prediction: 236295  -  Actual: 240000  -  Accuracy: 98.46%
# Prediction: 161236  -  Actual: 161500  -  Accuracy: 99.84%
# Prediction: 321260  -  Actual: 333168  -  Accuracy: 96.43%
# Prediction: 352119  -  Actual: 415298  -  Accuracy: 84.79%
# Prediction: 175238  -  Actual: 175000  -  Accuracy: 99.86%
# Prediction: 105346  -  Actual:  55993  -  Accuracy: 11.86%
# Prediction: 351658  -  Actual: 335000  -  Accuracy: 95.03%
# Prediction: 137033  -  Actual: 134000  -  Accuracy: 97.74%
# Prediction: 249656  -  Actual: 249700  -  Accuracy: 99.98%
# Prediction: 132296  -  Actual: 139000  -  Accuracy: 95.18%
# Prediction: 232077  -  Actual: 227680  -  Accuracy: 98.07%
# Prediction: 149439  -  Actual: 164000  -  Accuracy: 91.12%
# Prediction:  82456  -  Actual:  95000  -  Accuracy: 86.80%
# Prediction: 187520  -  Actual: 198900  -  Accuracy: 94.28%
# Prediction: 155665  -  Actual: 141000  -  Accuracy: 89.60%
# Prediction: 199731  -  Actual: 231500  -  Accuracy: 86.28%
# Prediction:  88909  -  Actual:  87000  -  Accuracy: 97.81%
# Prediction: 113883  -  Actual: 127500  -  Accuracy: 89.32%
# Prediction: 140722  -  Actual: 140000  -  Accuracy: 99.48%
# Prediction: 139922  -  Actual: 124500  -  Accuracy: 87.61%
# Prediction: 184114  -  Actual: 179900  -  Accuracy: 97.66%
# Prediction: 136362  -  Actual: 130000  -  Accuracy: 95.11%
# Prediction: 187316  -  Actual: 165000  -  Accuracy: 86.47%
# Prediction: 250677  -  Actual: 242000  -  Accuracy: 96.41%
# Prediction: 212821  -  Actual: 195000  -  Accuracy: 90.86%
# Prediction: 127858  -  Actual:  94750  -  Accuracy: 65.06%
# Prediction: 159300  -  Actual: 152000  -  Accuracy: 95.20%
# Prediction: 244913  -  Actual: 256300  -  Accuracy: 95.56%
# Prediction: 135974  -  Actual: 135000  -  Accuracy: 99.28%
# Prediction: 360762  -  Actual: 394432  -  Accuracy: 91.46%
# Prediction: 225140  -  Actual: 216500  -  Accuracy: 96.01%
# Prediction: 124036  -  Actual: 138500  -  Accuracy: 89.56%
# Prediction: 114256  -  Actual: 116000  -  Accuracy: 98.50%
# Prediction: 142648  -  Actual: 132500  -  Accuracy: 92.34%
# Prediction:  73224  -  Actual: 109500  -  Accuracy: 66.87%
# Prediction: 178194  -  Actual: 174000  -  Accuracy: 97.59%
# Prediction: 476443  -  Actual: 555000  -  Accuracy: 85.85%
# Prediction: 184584  -  Actual: 183900  -  Accuracy: 99.63%
# Prediction: 155115  -  Actual: 160000  -  Accuracy: 96.95%
# Prediction: 248233  -  Actual: 270000  -  Accuracy: 91.94%
# Prediction: 180092  -  Actual: 187100  -  Accuracy: 96.25%
# Prediction: 129237  -  Actual: 128500  -  Accuracy: 99.43%
# Prediction: 160912  -  Actual: 140000  -  Accuracy: 85.06%
# Prediction: 364834  -  Actual: 360000  -  Accuracy: 98.66%
# Prediction:  77766  -  Actual:  68500  -  Accuracy: 86.47%
# Prediction: 166267  -  Actual: 146000  -  Accuracy: 86.12%
# Prediction: 100708  -  Actual:  89500  -  Accuracy: 87.48%
# Prediction: 137332  -  Actual: 148000  -  Accuracy: 92.79%
# Prediction: 108911  -  Actual:  94500  -  Accuracy: 84.75%
# Prediction: 121811  -  Actual: 130500  -  Accuracy: 93.34%
# Prediction: 193238  -  Actual: 177000  -  Accuracy: 90.83%
# Prediction: 127194  -  Actual: 153900  -  Accuracy: 82.65%
# Prediction: 172450  -  Actual: 192140  -  Accuracy: 89.75%
# Prediction: 206324  -  Actual: 215000  -  Accuracy: 95.96%
# Prediction: 134960  -  Actual: 148500  -  Accuracy: 90.88%
# Prediction: 207901  -  Actual: 187500  -  Accuracy: 89.12%
# Prediction: 213895  -  Actual: 230000  -  Accuracy: 93.00%
# Prediction: 139782  -  Actual: 143000  -  Accuracy: 97.75%
# Prediction: 155212  -  Actual: 151500  -  Accuracy: 97.55%
# Prediction: 190875  -  Actual: 207500  -  Accuracy: 91.99%
# Prediction: 239253  -  Actual: 263435  -  Accuracy: 90.82%
# Prediction: 123342  -  Actual: 133900  -  Accuracy: 92.12%
# Prediction: 246576  -  Actual: 246578  -  Accuracy: 100.00%
# Prediction: 223367  -  Actual: 233230  -  Accuracy: 95.77%
# Prediction: 154116  -  Actual: 158000  -  Accuracy: 97.54%
# Prediction: 131397  -  Actual:  82500  -  Accuracy: 40.73%
# Prediction: 213948  -  Actual: 213000  -  Accuracy: 99.55%
# Prediction: 143028  -  Actual: 135000  -  Accuracy: 94.05%
# Prediction: 141379  -  Actual: 155000  -  Accuracy: 91.21%
# Prediction: 148871  -  Actual: 178400  -  Accuracy: 83.45%
# Prediction:  92174  -  Actual: 110000  -  Accuracy: 83.80%
# Prediction: 224974  -  Actual: 230000  -  Accuracy: 97.82%
# Prediction: 361140  -  Actual: 395192  -  Accuracy: 91.38%
# Prediction: 194706  -  Actual: 191000  -  Accuracy: 98.06%
# Prediction: 177752  -  Actual: 163500  -  Accuracy: 91.28%
# Prediction: 193070  -  Actual: 189000  -  Accuracy: 97.85%
# Prediction: 333843  -  Actual: 340000  -  Accuracy: 98.19%
# Prediction: 139481  -  Actual: 142953  -  Accuracy: 97.57%
# Prediction: 314071  -  Actual: 318000  -  Accuracy: 98.76%
# Prediction: 123342  -  Actual: 107400  -  Accuracy: 85.16%
# Prediction: 244561  -  Actual: 231500  -  Accuracy: 94.36%
# Prediction: 218473  -  Actual: 227875  -  Accuracy: 95.87%
# Prediction: 291335  -  Actual: 147000  -  Accuracy: 1.81%
# Prediction: 138382  -  Actual: 148500  -  Accuracy: 93.19%
# Prediction: 101338  -  Actual: 122000  -  Accuracy: 83.06%
# Prediction:  60458  -  Actual:  61000  -  Accuracy: 99.11%
# Prediction: 178292  -  Actual: 164500  -  Accuracy: 91.62%
# Prediction: 234588  -  Actual: 254000  -  Accuracy: 92.36%
# Prediction: 114260  -  Actual: 108000  -  Accuracy: 94.20%
# Prediction: 124375  -  Actual: 134500  -  Accuracy: 92.47%
# Prediction: 135648  -  Actual: 153500  -  Accuracy: 88.37%
# Prediction: 166462  -  Actual: 219500  -  Accuracy: 75.84%
# Prediction: 112837  -  Actual: 124000  -  Accuracy: 91.00%
# Prediction: 125437  -  Actual: 133000  -  Accuracy: 94.31%
# Prediction: 138517  -  Actual: 142600  -  Accuracy: 97.14%
# Prediction: 329844  -  Actual: 315000  -  Accuracy: 95.29%
# Prediction: 129187  -  Actual:  79500  -  Accuracy: 37.50%
# Prediction: 117481  -  Actual: 123000  -  Accuracy: 95.51%
# Prediction: 116551  -  Actual:  85000  -  Accuracy: 62.88%
# Prediction: 311617  -  Actual: 315000  -  Accuracy: 98.93%
# Prediction: 157562  -  Actual: 162000  -  Accuracy: 97.26%
# Prediction: 158230  -  Actual: 140000  -  Accuracy: 86.98%
# Prediction: 396821  -  Actual: 377426  -  Accuracy: 94.86%
# Prediction:  67462  -  Actual:  80000  -  Accuracy: 84.33%
# Prediction: 135949  -  Actual: 105500  -  Accuracy: 71.14%
# Prediction: 137133  -  Actual: 139950  -  Accuracy: 97.99%
# Prediction: 158261  -  Actual: 165000  -  Accuracy: 95.92%
# Prediction: 113477  -  Actual: 109500  -  Accuracy: 96.37%
# Prediction: 162516  -  Actual: 198500  -  Accuracy: 81.87%
# Prediction: 212567  -  Actual: 226000  -  Accuracy: 94.06%
# Prediction: 173112  -  Actual: 146500  -  Accuracy: 81.83%
# Prediction: 195115  -  Actual: 183000  -  Accuracy: 93.38%
# Prediction: 212230  -  Actual: 185000  -  Accuracy: 85.28%
# Prediction: 125275  -  Actual: 130250  -  Accuracy: 96.18%
# Prediction: 356492  -  Actual: 410000  -  Accuracy: 86.95%
# Prediction: 128707  -  Actual: 110000  -  Accuracy: 82.99%
# Prediction: 172748  -  Actual: 168500  -  Accuracy: 97.48%
# Prediction: 188477  -  Actual: 183200  -  Accuracy: 97.12%
# Prediction: 209634  -  Actual: 187000  -  Accuracy: 87.90%
# Prediction: 151688  -  Actual: 159950  -  Accuracy: 94.84%
# Prediction: 145403  -  Actual: 148000  -  Accuracy: 98.25%
# Prediction: 210828  -  Actual: 214000  -  Accuracy: 98.52%
# Prediction: 137515  -  Actual: 167000  -  Accuracy: 82.34%
# Prediction: 163066  -  Actual: 144000  -  Accuracy: 86.76%
# Prediction: 287260  -  Actual: 370878  -  Accuracy: 77.45%
# Prediction: 269857  -  Actual: 277500  -  Accuracy: 97.25%
# Prediction: 235521  -  Actual: 223500  -  Accuracy: 94.62%
# Prediction: 148047  -  Actual: 134432  -  Accuracy: 89.87%
# Prediction: 260843  -  Actual: 475000  -  Accuracy: 54.91%
# Prediction: 227348  -  Actual: 289000  -  Accuracy: 78.67%
# Prediction: 202802  -  Actual: 175500  -  Accuracy: 84.44%
# Prediction: 128649  -  Actual: 135750  -  Accuracy: 94.77%
# Prediction: 115430  -  Actual: 118964  -  Accuracy: 97.03%
# Prediction: 199444  -  Actual: 203000  -  Accuracy: 98.25%
# Prediction: 252909  -  Actual: 274725  -  Accuracy: 92.06%
# Prediction: 381305  -  Actual: 402000  -  Accuracy: 94.85%
# Prediction: 133551  -  Actual: 178000  -  Accuracy: 75.03%
# Prediction: 116231  -  Actual: 103600  -  Accuracy: 87.81%
# Prediction: 133073  -  Actual: 129500  -  Accuracy: 97.24%
# Prediction: 142782  -  Actual: 127000  -  Accuracy: 87.57%
# Prediction: 110165  -  Actual:  91500  -  Accuracy: 79.60%
# Prediction: 140068  -  Actual: 155000  -  Accuracy: 90.37%
# Prediction:  94799  -  Actual: 113000  -  Accuracy: 83.89%
# Prediction: 186228  -  Actual: 202900  -  Accuracy: 91.78%
# Prediction: 253567  -  Actual: 252000  -  Accuracy: 99.38%
# Prediction: 185088  -  Actual: 225000  -  Accuracy: 82.26%
# Prediction: 140220  -  Actual: 128500  -  Accuracy: 90.88%
# Prediction: 404482  -  Actual: 278000  -  Accuracy: 54.50%
# Prediction: 153901  -  Actual: 160000  -  Accuracy: 96.19%
# Prediction: 119893  -  Actual: 118000  -  Accuracy: 98.40%
# Prediction: 248161  -  Actual: 255900  -  Accuracy: 96.98%
# Prediction: 246628  -  Actual: 224500  -  Accuracy: 90.14%
# Prediction: 134416  -  Actual: 138500  -  Accuracy: 97.05%
# Prediction: 240748  -  Actual: 248000  -  Accuracy: 97.08%
# Prediction: 361650  -  Actual: 319000  -  Accuracy: 86.63%
# Prediction:  63240  -  Actual:  39300  -  Accuracy: 39.08%
# Prediction: 141877  -  Actual: 174900  -  Accuracy: 81.12%
# Prediction: 232334  -  Actual: 262500  -  Accuracy: 88.51%
# Prediction: 144402  -  Actual: 138000  -  Accuracy: 95.36%
# Prediction: 221844  -  Actual: 210000  -  Accuracy: 94.36%
# Prediction: 279732  -  Actual: 215000  -  Accuracy: 69.89%
# Prediction: 142625  -  Actual: 145500  -  Accuracy: 98.02%
# Prediction: 290623  -  Actual: 280000  -  Accuracy: 96.21%
# Prediction: 143600  -  Actual: 144000  -  Accuracy: 99.72%
# Prediction: 125787  -  Actual: 135900  -  Accuracy: 92.56%
# Prediction: 127601  -  Actual: 129000  -  Accuracy: 98.92%
# Prediction: 263268  -  Actual: 175000  -  Accuracy: 49.56%
# Prediction: 156120  -  Actual: 154000  -  Accuracy: 98.62%
# Prediction: 155395  -  Actual: 143000  -  Accuracy: 91.33%
# Prediction: 134776  -  Actual: 141000  -  Accuracy: 95.59%
# Prediction: 150687  -  Actual: 144900  -  Accuracy: 96.01%
# Prediction: 217347  -  Actual: 209500  -  Accuracy: 96.25%
# Prediction: 116309  -  Actual: 160000  -  Accuracy: 72.69%
# Prediction: 425559  -  Actual: 556581  -  Accuracy: 76.46%
# Prediction:  83075  -  Actual:  78000  -  Accuracy: 93.49%
# Prediction: 193807  -  Actual: 181000  -  Accuracy: 92.92%
# Prediction: 118668  -  Actual: 143000  -  Accuracy: 82.98%
# Prediction: 102531  -  Actual:  87000  -  Accuracy: 82.15%
# Prediction: 223746  -  Actual: 224000  -  Accuracy: 99.89%
# Prediction:  65744  -  Actual:  82000  -  Accuracy: 80.18%
# Prediction: 169113  -  Actual: 170000  -  Accuracy: 99.48%
# Prediction: 163303  -  Actual: 207500  -  Accuracy: 78.70%
# Prediction: 193504  -  Actual: 191000  -  Accuracy: 98.69%
# Prediction: 131577  -  Actual: 139000  -  Accuracy: 94.66%
# Prediction: 189017  -  Actual: 183500  -  Accuracy: 96.99%
# Prediction: 138326  -  Actual: 144000  -  Accuracy: 96.06%
# Prediction: 145005  -  Actual: 132000  -  Accuracy: 90.15%
# Prediction: 184717  -  Actual: 184000  -  Accuracy: 99.61%
# Prediction: 279753  -  Actual: 250000  -  Accuracy: 88.10%
# Prediction:  87143  -  Actual:  88000  -  Accuracy: 99.03%
# Prediction: 275527  -  Actual: 268000  -  Accuracy: 97.19%
# Prediction: 233351  -  Actual: 219500  -  Accuracy: 93.69%
# Prediction: 140331  -  Actual: 141000  -  Accuracy: 99.53%
# Prediction: 499070  -  Actual: 582933  -  Accuracy: 85.61%
# Prediction: 267333  -  Actual: 392500  -  Accuracy: 68.11%
# Prediction:  97469  -  Actual: 102000  -  Accuracy: 95.56%
# Prediction: 116869  -  Actual: 129900  -  Accuracy: 89.97%
# Prediction: 113451  -  Actual: 129000  -  Accuracy: 87.95%
# Prediction: 163452  -  Actual: 176000  -  Accuracy: 92.87%
# Prediction: 222004  -  Actual: 265900  -  Accuracy: 83.49%
# Prediction: 376896  -  Actual: 394617  -  Accuracy: 95.51%
# Prediction: 175204  -  Actual: 176000  -  Accuracy: 99.55%
# Prediction: 199937  -  Actual: 202500  -  Accuracy: 98.73%
# Prediction: 229829  -  Actual: 232000  -  Accuracy: 99.06%
# Prediction: 235488  -  Actual: 278000  -  Accuracy: 84.71%
# Prediction: 192230  -  Actual: 185000  -  Accuracy: 96.09%
# Prediction: 208509  -  Actual: 219500  -  Accuracy: 94.99%
# Prediction: 177773  -  Actual: 173900  -  Accuracy: 97.77%
# Prediction: 222401  -  Actual: 192000  -  Accuracy: 84.17%
# Prediction: 102286  -  Actual: 115000  -  Accuracy: 88.95%
# Prediction: 117582  -  Actual: 114504  -  Accuracy: 97.31%
# Prediction: 197884  -  Actual: 217000  -  Accuracy: 91.19%
# Prediction: 129672  -  Actual: 117000  -  Accuracy: 89.17%
# Prediction: 197354  -  Actual: 127000  -  Accuracy: 44.60%

# %%
print("Most accurate prediction: {:.2f}%".format(accuracies.max()))
print("Least accurate prediction: {:.2f}%".format(accuracies.min()))
print("Average accuracy: {:.2f}%".format(averageAcc))
print("Mean Error: {:.2f}%, std: {:.2f}%".format(mean, std))
# Out:
# Most accurate prediction: 100.00%
# Least accurate prediction: 1.81%
# Average accuracy: 89.16%
# Mean Error: 10.84%, std: 13.00%

# %% [markdown]
# Mean absolute percentage error is plotted against epochs for both training and validation data.

# %%
# Plot history: MAE
plt.plot(history.history['loss'], label='MAE (training data)')
plt.plot(history.history['val_loss'], label='MAE (validation data)')
plt.title('MAE for Ames Housing Data')
plt.ylabel('Mean Absolute Error (%)')
plt.xlabel('Epoch (#)')
plt.legend(loc="upper right")
plt.show()
